# %%
import pickle

objects = []
with (open("faces.pkl", "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break

# %%
objects
# Out:
# [(array([[ 0.00211341,  0.08455166, -0.02997098, ...,  0.03978166,
#           -0.01253698,  0.04965165],
#          [ 0.04756892,  0.04163751, -0.025301  , ...,  0.06114318,
#            0.0024831 , -0.07842508],
#          [ 0.02989303, -0.00699744,  0.01829329, ...,  0.05700355,
#           -0.00354063, -0.00267983],
#          ...,
#          [-0.02746511, -0.03410396, -0.01868453, ...,  0.07232936,
#           -0.03472762, -0.00968119],
#          [-0.0321466 ,  0.02983825, -0.00657698, ...,  0.00498388,
#           -0.04945319, -0.02651016],
#          [ 0.02375548, -0.00720437, -0.04675656, ...,  0.00399839,
#           -0.03334536,  0.0136312 ]], dtype=float32),
#   ['Amine El Khiati',
#    'Amine El Khiati',
#    'Amine El Khiati',
#    'Clara Bomy',
#    'Clara Bomy',
#    'Clara Bomy',
#    'Clara Bomy',
#    'Clara Bomy',
#    'Hedi Zekri',
#    'Hedi Zekri',
#    'Hedi Zekri',
#    'Hedi Zekri',
#    'Louis Hochart',
#    'Louis Hochart',
#    'Louis Hochart',
# ...

# %%
with open('faces.pkl', 'rb') as f:
    x = pickle.load(f)

# %%
x
# Out:
# (array([[ 0.00211341,  0.08455166, -0.02997098, ...,  0.03978166,
#          -0.01253698,  0.04965165],
#         [ 0.04756892,  0.04163751, -0.025301  , ...,  0.06114318,
#           0.0024831 , -0.07842508],
#         [ 0.02989303, -0.00699744,  0.01829329, ...,  0.05700355,
#          -0.00354063, -0.00267983],
#         ...,
#         [-0.02746511, -0.03410396, -0.01868453, ...,  0.07232936,
#          -0.03472762, -0.00968119],
#         [-0.0321466 ,  0.02983825, -0.00657698, ...,  0.00498388,
#          -0.04945319, -0.02651016],
#         [ 0.02375548, -0.00720437, -0.04675656, ...,  0.00399839,
#          -0.03334536,  0.0136312 ]], dtype=float32),
#  ['Amine El Khiati',
#   'Amine El Khiati',
#   'Amine El Khiati',
#   'Clara Bomy',
#   'Clara Bomy',
#   'Clara Bomy',
#   'Clara Bomy',
#   'Clara Bomy',
#   'Hedi Zekri',
#   'Hedi Zekri',
#   'Hedi Zekri',
#   'Hedi Zekri',
#   'Louis Hochart',
#   'Louis Hochart',
#   'Louis Hochart',
#   'Louis Hochart',
# ...
